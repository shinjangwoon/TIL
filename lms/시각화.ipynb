# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x =  np.arange(1,30)
y =  x**3
plt.plot(x,y)
plt.show()

# %%
x = np.arange(1,30)
y = x**2
y2 = x**2 + 5*2
plt.plot(x,y,y2)
plt.show()

# %%
import numpy as np
x = np.arange(1,30)
y = x**2
y2 = x**2 + 5*x
y3 = x**2 + 10*x + 20
plt.plot(x,y,'r--', y2, 'b--', y3, 'k--')
plt.show()

# %%
x = np.arange(1,30)
y = x**3
plt.plot(x,y,marker='+', markersize=5, color='b')
plt.show()

# %%
x = np.arange(1,30)
y = x**2
y2 = x**2 + 5*x
plt.plot(x,y,marker='+', markersize=5, color='b')
plt.plot(x,y2,marker='o', markersize=5, color='r')
plt.show()

# %%
import pandas as pd
df = pd.read_csv('C:/Users/wkddn/AI_IPA/IPA_Day5/iris.csv', names=['sepal_length','sepal_width','petal_length', 'petal_width', 'species'])
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
y = np.array([0, 0, 3, 7, 5, 3, 5, 0, 1])
x = 
plt.
plt.show()

# %%
d1.plot(
plt.title('학생성적')

plt.show()

# %%
d1['국어'].plot 
plt.title('학생성적')
plt.xlabel('이름')
plt.ylabel('점수')
plt.show()

# %%
d1['성별']=['남','여','남','여','여','남']

# %%
d1

# %%
dg = df.groupby('species')
cnt = 1
plt.figure(figsize=(15,5))
for key, g in dg:
    plt.subplot(1,3,cnt)
    plt.scatter(g['sepal_length'], g['sepal_width'])
    plt.title('IRIS: '+key)
    plt.xlabel('sepal_length')
    plt.ylabel('sepal_width')
    cnt+=1
plt.show()

# %%
img1 = plt.imread('icecream.jpg')
plt.imshow(img1)
plt.show()

# %%
 type(img1)
# Out:
# numpy.ndarray

# %%
img1.shape
# Out:
# (359, 640, 3)

# %%
img1.ndim
# Out:
# 3

# %%
plt.imshow(img1[:,:,0], cmap='Reds')

# %%
plt.imshow(img1[:,:,1], cmap='Greens')

# %%
 plt.imshow(img1[:,:,2], cmap='Blues')

# %%
import seaborn as sns
sns.set()

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
plt.figure(figsize=(5,5))
sns.regplot(x='petal_length', y='petal_width', data=df)
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.distplot(df['petal_length'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(5,5))
sns.swarmplot(x='petal_length', y='petal_width', data=df, hue='species')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 57.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 75.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 71.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.countplot(x='species', palette='Set2', data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,2,1)
sns.boxplot(x='species', y='sepal_length', data=df)
plt.subplot(2,2,2)
sns.boxplot(x='species', y='sepal_width', data=df)
plt.subplot(2,2,3)
sns.boxplot(x='species', y='sepal_length', data=df)
plt.subplot(2,2,4)
sns.boxplot(x='species', y='sepal_width', data=df)
plt.show()

# %%
sns.pairplot(df, hue='species', height=1.5)
