# %%
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_csv('sports.csv', index_col=0)
df
# Out:
#             Male  Female
# Swimming     103     178
# Baseball     363     289
# Basketball   151      97
# Golf         154     232
# Soccer       413     109
# Bowling       88     129

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='barh', stacked=True)
# Out:
# <AxesSubplot:>

# %%
df['Female'].plot(kind='bar')
# Out:
# <AxesSubplot:>
